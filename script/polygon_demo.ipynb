# %%
from datetime import datetime

from vnpy.trader.datafeed import get_datafeed
from vnpy.trader.object import (
    Exchange,
    HistoryRequest,
    Interval
)

# %%
datafeed = get_datafeed()
datafeed.init()
# Out:
# True

# %%
req = HistoryRequest(
    symbol="SPY",
    exchange=Exchange.NYSE,
    start=datetime(2025, 8, 1),
    end=datetime(2025, 8, 12),
    interval=Interval.MINUTE
)

bars = datafeed.query_bar_history(req)

# %%
print(len(bars))
print(bars[0])
print(bars[-1])
# Out:
# 6157
# BarData(gateway_name='POLYGON', extra=None, symbol='SPY', exchange=<Exchange.NYSE: 'NYSE'>, datetime=datetime.datetime(2025, 8, 1, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')), interval=<Interval.MINUTE: '1m'>, volume=176571, turnover=112581422.4006, open_interest=0, open_price=637.55, high_price=637.72, low_price=637.45, close_price=637.67)
# BarData(gateway_name='POLYGON', extra=None, symbol='SPY', exchange=<Exchange.NYSE: 'NYSE'>, datetime=datetime.datetime(2025, 8, 12, 0, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')), interval=<Interval.MINUTE: '1m'>, volume=229636, turnover=146362821.7568, open_interest=0, open_price=637.87, high_price=637.89, low_price=637.79, close_price=637.8401)
